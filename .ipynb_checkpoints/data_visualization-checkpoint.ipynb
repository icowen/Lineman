# %%
# %matplotlib inline

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import HTML
from matplotlib.animation import FuncAnimation

# %%
data = pd.read_csv('netdata.csv')
data.head()
# Out:
#    X      gameId  playId  frame.id  OL_C_x     OL_C_y  OL_LG_x    OL_LG_y  \
# 0  1  2017090700      68         1   26.59  23.433333    26.16  24.993333
# 1  2  2017090700      68         2   26.59  23.423333    26.16  24.993333
# 2  3  2017090700      68         3   26.58  23.423333    26.16  24.993333
# 3  4  2017090700      68         4   26.58  23.423333    26.16  24.993333
# 4  5  2017090700      68         5   26.57  23.423333    26.16  24.983333
#
#    OL_LT_x    OL_LT_y  ...  Def_9_x    Def_9_y  Def_10_x   Def_10_y  Def_11_x  \
# 0    26.03  26.723333  ...    35.38  35.143333     42.49  24.393333     28.47
# 1    26.03  26.723333  ...    35.37  35.143333     42.49  24.403333     28.47
# 2    26.03  26.723333  ...    35.37  35.143333     42.50  24.413333     28.47
# 3    26.03  26.723333  ...    35.37  35.143333     42.52  24.453333     28.47
# 4    26.03  26.723333  ...    35.37  35.153333     42.64  24.673333     28.48
#
#     Def_11_y  PlayResult  sack.ind  PassResult  num_vec
# 0  43.843333           0         0           I        1
# 1  43.843333           0         0           I        2
# 2  43.843333           0         0           I        3
# 3  43.843333           0         0           I        4
# 4  43.843333           0         0           I        5
#
# [5 rows x 62 columns]

# %%
data.drop('X', inplace=True, axis=1)
data.fillna('Run', inplace=True)
print(f'New dimensions of DataFrame: {data.shape}')
# Out:
# New dimensions of DataFrame: (558908, 61)

# %%
num_plays = data["playId"].unique().size
print(f'Number of unique plays: {num_plays}')
print(f'Average number of frames per play {round(data.shape[0] / num_plays, 2)}')
# Out:
# Number of unique plays: 3600
# Average number of frames per play 155.25

# %%
gameId = 2017090700
playId = 68
play = data.loc[(data["playId"] == playId) & (data["gameId"] == gameId)]

# %%
# Create figure
fig, ax = plt.subplots()
fig.set_tight_layout(True)
plt.xticks([], [])
plt.yticks([], [])

# Draw field dimensions
field_length = 120
field_width = 160 / 3
ax.set_xlim([0, field_length])
ax.set_ylim([0, field_width])
ax.set_facecolor('green')

# Add end zones
ax.fill_between([0, 10], field_width, color='maroon')
ax.fill_between([110, field_length], field_width, color='gold')

# Add yard lines and markings
for i in range(1, 12):
    yard_line = i * 10
    next_yard_line = (i + 1) * 10 + 1
    ax.axvline(yard_line, c='white', zorder=0)
    if i < 6: ax.annotate(yard_line, (next_yard_line, 5), c='white')
    elif i < 10: ax.annotate(100 - yard_line, (next_yard_line, 5), c='white')

# Overlay with an empty scatter plot
scat = ax.scatter([], [], s=16, edgecolors='black')
plt.show()

# %%
def get_new_x_y(frame_df):
    # Find columns with coordinate data
    x_cols = [c for c in frame_df.columns if re.match('.*_x$|^X_', c)]
    y_cols = [c for c in frame_df.columns if re.match('.*_y$|^Y_', c)]
    
    # Get coordinates for each player in the frame
    x = [frame_df[x].values[0] for x in x_cols]
    y = [frame_df[y].values[0] for y in y_cols]
    
    # Identify a team for each pair of coordinates
    labels = ['OL'] * 5 + ['def'] * 5 + ['off'] * 6 + ['def'] * 11
    
    # Return coordinate/team data frame
    return pd.DataFrame(dict(x=x, y=y, label=labels))


def update(frame):
    # Get data for this frame 
    frame_df = play[play["frame.id"] == frame]
    
    # Clean coordinates
    df = get_new_x_y(frame_df)
    
    # Convert coordinate data frame to list of tuples and plot
    x_y = [(x, y) for x, y in zip(df['x'], df['y'])]
    scat.set_offsets(x_y)
    scat.set_edgecolors('black')
    
    # Identify offense vs defense
    colors = ['r' if x == 'def' else 'b' for x in df['label']]
    scat.set_color(colors)
    
    # Update frame label
    ax.set_xlabel(f'Frame {frame}')


anim = FuncAnimation(fig, update, frames=play["frame.id"], interval=100)

# %%
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img8b985909287d4e31803f998bedf137c2">
#   <div class="anim-controls">
#     <input id="_anim_slider8b985909287d4e31803f998bedf137c2" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim8b985909287d4e31803f998bedf137c2.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim8b985909287d4e31803f998bedf137c2.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select8b985909287d4e31803f998bedf137c2" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_8b985909287d4e31803f998bedf137c2"
#              >
#       <label for="_anim_radio1_8b985909287d4e31803f998bedf137c2">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_8b985909287d4e31803f998bedf137c2"
#              checked>
#       <label for="_anim_radio2_8b985909287d4e31803f998bedf137c2">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_8b985909287d4e31803f998bedf137c2"
#              >
#       <label for="_anim_radio3_8b985909287d4e31803f998bedf137c2">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8b985909287d4e31803f998bedf137c2";
#     var slider_id = "_anim_slider8b985909287d4e31803f998bedf137c2";
#     var loop_select_id = "_anim_loop_select8b985909287d4e31803f998bedf137c2";
#     var frames = new Array(87);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8GearUAAAVXElEQVR4nO3de3hU9Z2A8XcmdxIuKggKGBTBRZZL\
# KCgs9VqrrCheHry2iuJdt1V7ca121a5t9ant6tquK7QqlHopi1Jt1Yp3vICKQPGCiEoUEQgEQ0gg\
# IcnM/jEQTEFBmsw5P3w/z5PHnMkc5juTmbyeMzNnEul0Oo0kSYFJRj2AJEk7w4BJkoJkwCRJQTJg\
# kqQgGTBJUpAMmCQpSAZMkhQkAyZJCpIBkyQFyYBJkoKUu7Mrtksk6NSak+ykRDLJJ11Tkc7Qt3Nf\
# AN5d/a5zOIdzBDBHHGaI2xwlqfdIEO3fUoDyZbD60x07wmFiZ4+FuHciwUU7s2IbuOGGaC//2XHP\
# AnDE5COcwzmcI4A54jBD3OY4vC7aGTYbOhbmvLljWXIXoiQpSAZMkhQkAyZJCpIBkyQFyYBJkoJk\
# wCRJQTJgkqQgGTBJUpAMmCQpSA
